# %% [markdown]
# <a href="https://colab.research.google.com/github/qgallouedec/panda-gym/blob/colab/PickAndPlace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `panda-gym` code example
#
# ## Install `panda-gym`

# %%
# %pip install panda-gym
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: panda-gym in /home/pope/.local/lib/python3.10/site-packages (3.0.8)
# Requirement already satisfied: gymnasium>=0.26 in /home/pope/.local/lib/python3.10/site-packages (from panda-gym) (1.2.1)
# Requirement already satisfied: pybullet in /home/pope/.local/lib/python3.10/site-packages (from panda-gym) (3.2.7)
# Requirement already satisfied: numpy<2 in /home/pope/.local/lib/python3.10/site-packages (from panda-gym) (1.24.3)
# Requirement already satisfied: scipy in /home/pope/.local/lib/python3.10/site-packages (from panda-gym) (1.15.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/pope/.local/lib/python3.10/site-packages (from gymnasium>=0.26->panda-gym) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/pope/.local/lib/python3.10/site-packages (from gymnasium>=0.26->panda-gym) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/pope/.local/lib/python3.10/site-packages (from gymnasium>=0.26->panda-gym) (0.0.4)
# WARNING: Error parsing dependencies of send2trash: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     sys-platform (=="darwin") ; extra == 'objc'
#                  ~^
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Interract

# %%
import gymnasium as gym
import panda_gym

env = gym.make("PandaPickAndPlace-v3", render_mode="rgb_array")
observation, info = env.reset()

images = [env.render()]
for _ in range(200):
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    images.append(env.render())

    if terminated or truncated:
        observation, info = env.reset()
        images.append(env.render())

env.close()
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886

# %% [markdown]
# ## Convert into animation

# %%
# %pip install numpngw
from numpngw import write_apng

write_apng("anim.png", images, delay=40)  # real-time rendering = 40 ms between frames
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpngw
#   Downloading numpngw-0.1.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.6.0 in /home/pope/.local/lib/python3.10/site-packages (from numpngw) (1.24.3)
# Downloading numpngw-0.1.4-py3-none-any.whl (21 kB)
# WARNING: Error parsing dependencies of send2trash: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     sys-platform (=="darwin") ; extra == 'objc'
#                  ~^
# Installing collected packages: numpngw
# Successfully installed numpngw-0.1.4
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Show animation

# %%
from IPython.display import Image

Image(filename="anim.png")
